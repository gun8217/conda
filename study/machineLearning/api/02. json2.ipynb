# %%
import requests
url = 'http://apis.data.go.kr/B551011/KorService1/detailPetTour1'
params = {
    'serviceKey' : 'LS/k7aFQ2gzJrqJtruXv2Ua6HdUwR+Fvp1tO11lQagb60lUfvrVnApQ6tuEULO50Trukt7eWlEGQR8Ewmc5Aeg==',
    'MobileOS' : 'WIN',
    'MobileApp' : 'APP',
    '_type' : 'JSON' }

response = requests.get(url, params=params)
response
# Out:
# <Response [200]>

# %%
json_data = response.json()
json_data
# Out:
# {'response': {'header': {'resultCode': '0000', 'resultMsg': 'OK'},
#   'body': {'items': {'item': [{'contentid': '1019041',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1021339',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1032715',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '일부구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1037031',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1039170',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '반려동물의 몸이 외부에 노출되면 동반 불가',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '반려동물 유모차 탑승,이동장(켄넬)사용'},
#      {'contentid': '1059479',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '- 안전을 위해 목줄은 2m이내로 유지 \n- 별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1083960',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '전구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1100498',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '',
#       'acmpyTypeCd': '일부구역 동반가능',
#       'relaPosesFclty': '',
#       'relaFrnshPrdlst': '',
#       'etcAcmpyInfo': '- 별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수 \n- 주거공간과 함께 구성된 여행지로 실내 시설 입장 관련은 개별 문의 필요',
#       'relaPurcPrdlst': '',
#       'acmpyPsblCpam': '전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)',
#       'relaRntlPrdlst': '',
#       'acmpyNeedMtr': ''},
#      {'contentid': '1115613',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '없음',
#       'acmpyTypeCd': '',
#       'relaPosesFclty': '산책로',
#       'relaFrnshPrdlst': '배변수거함',
#       'etcAcmpyInfo': '대형견(25kg이상)까지 가능',
#       'relaPurcPrdlst': '없음',
#       'acmpyPsblCpam': '',
#       'relaRntlPrdlst': '없음',
#       'acmpyNeedMtr': '목줄 착용'},
#      {'contentid': '1119452',
#       'petTursmInfo': '',
#       'relaAcdntRiskMtr': '이용방법 및 규칙 비치',
#       'acmpyTypeCd': '',
#       'relaPosesFclty': '펜스,산책로,놀이기구',
#       'relaFrnshPrdlst': '배변봉투,식기 또는 물그릇',
#       'etcAcmpyInfo': '대형견 가능 (25kg이상), 반려동물 놀이터 이용시 동물등록이 완료된 반려견만 입장 가능',
#       'relaPurcPrdlst': '없음',
#       'acmpyPsblCpam': '',
#       'relaRntlPrdlst': '없음',
#       'acmpyNeedMtr': '입마개 착용,목줄 착용'}]},
#    'numOfRows': 10,
#    'pageNo': 1,
#    'totalCount': 1092}}}

# %%
import pandas as pd

df = pd.DataFrame(json_data['response']['body']['items']['item'])
df.head()
# Out:
#   contentid petTursmInfo relaAcdntRiskMtr acmpyTypeCd relaPosesFclty  \
# 0   1019041                                  전구역 동반가능
# 1   1021339                                  전구역 동반가능
# 2   1032715                                 일부구역 동반가능
# 3   1037031                                  전구역 동반가능
# 4   1039170                                  전구역 동반가능
#
#   relaFrnshPrdlst                         etcAcmpyInfo relaPurcPrdlst  \
# 0                  별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수
# 1                  별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수
# 2                  별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수
# 3                  별도의 쓰레기 처리 시설이 없으므로 배변봉투 지참 및 수거 필수
# 4                              반려동물의 몸이 외부에 노출되면 동반 불가
#
#                    acmpyPsblCpam relaRntlPrdlst           acmpyNeedMtr
# 0  전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)                                 목줄 착용
# 1  전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)                                 목줄 착용
# 2  전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)                                 목줄 착용
# 3  전 견종 출입 가능(맹견의 경우, 입마개 착용 필수)                                 목줄 착용
# 4                                                반려동물 유모차 탑승,이동장(켄넬)사용
